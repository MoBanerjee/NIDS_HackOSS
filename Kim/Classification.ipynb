# %%
import numpy as np 
import pandas as pd
from tqdm import tqdm

# %%
total_data = pd.read_csv("./FinalDatasets/TotalDataset_Engineered.csv")

# %%
total_data.head(5)
# Out:
#    Unnamed: 0          Date first seen  Duration Proto     Src IP Addr  \
# 0           0  2017-03-15 00:01:16.632     0.000   TCP   192.168.100.5
# 1           1  2017-03-15 00:01:16.552     0.000   TCP   192.168.100.5
# 2           2  2017-03-15 00:01:16.551     0.004   TCP  192.168.220.15
# 3           3  2017-03-15 00:01:16.631     0.004   TCP  192.168.220.16
# 4           4  2017-03-15 00:01:17.432     0.000   TCP   192.168.220.9
#
#    Src Pt     Dst IP Addr   Dst Pt  Packets  Bytes  ...  S  F   class  \
# 0     445  192.168.220.16  58844.0        1    108  ...  0  0  normal
# 1     445  192.168.220.15  48888.0        1    108  ...  0  0  normal
# 2   48888   192.168.100.5    445.0        2    174  ...  0  0  normal
# 3   58844   192.168.100.5    445.0        2    174  ...  0  0  normal
# 4   37884   192.168.100.5    445.0        1     66  ...  0  0  normal
#
#    attackType  year  month days hours  minutes  seconds
# 0        none  2017      3   15     0        1   16.632
# 1        none  2017      3   15     0        1   16.552
# 2        none  2017      3   15     0        1   16.551
# 3        none  2017      3   15     0        1   16.631
# 4        none  2017      3   15     0        1   17.432
#
# [5 rows x 24 columns]

# %%
total_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39643009 entries, 0 to 39643008
# Data columns (total 24 columns):
#  #   Column           Dtype
# ---  ------           -----
#  0   Unnamed: 0       int64
#  1   Date first seen  object
#  2   Duration         float64
#  3   Proto            object
#  4   Src IP Addr      object
#  5   Src Pt           int64
#  6   Dst IP Addr      object
#  7   Dst Pt           float64
#  8   Packets          int64
#  9   Bytes            int64
#  10  U                int64
#  11  A                int64
#  12  P                int64
#  13  R                int64
#  14  S                int64
#  15  F                int64
#  16  class            object
#  17  attackType       object
#  18  year             int64
#  19  month            int64
#  20  days             int64
#  21  hours            int64
#  22  minutes          int64
#  23  seconds          float64
# dtypes: float64(3), int64(15), object(6)
# memory usage: 7.1+ GB

# %%
# Removing none type attackType

total_data = total_data[total_data.attackType != "none"]

# %%
total_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5939551 entries, 14 to 39643001
# Data columns (total 24 columns):
#  #   Column           Dtype
# ---  ------           -----
#  0   Unnamed: 0       int64
#  1   Date first seen  object
#  2   Duration         float64
#  3   Proto            category
#  4   Src IP Addr      category
#  5   Src Pt           int64
#  6   Dst IP Addr      category
#  7   Dst Pt           float64
#  8   Packets          int64
#  9   Bytes            int64
#  10  U                int64
#  11  A                int64
#  12  P                int64
#  13  R                int64
#  14  S                int64
#  15  F                int64
#  16  class            object
#  17  attackType       object
#  18  year             int64
#  19  month            int64
#  20  days             int64
#  21  hours            int64
#  22  minutes          int64
#  23  seconds          float64
# dtypes: category(3), float64(3), int64(15), object(3)
# memory usage: 1.1+ GB

# %%
for col in ['Proto', 'Src IP Addr', 'Dst IP Addr']:
    total_data[col] = total_data[col].astype('category')

# %% [markdown]
# #### One concern I have with some of these features is that the featuers with IP Addresses I believe should be removed.
# #### Because what happens if we test on new data and that data contains an IP address that the model has never seen before and we are feeding the IP Address as a categorical column.
# #### So either we modify the data/model to take in the IP Address as a varying non-categorical value OR we drop the IP Addresses feature totally.

# %% [markdown]
# # Prepping for modeling

# %%
features = list(total_data.columns)
features.remove("Unnamed: 0")
features.remove("Date first seen")
features.remove("class")
features.remove("attackType")

# Dropping these columns for now
features.remove('Proto')
features.remove('Src IP Addr')
features.remove('Dst IP Addr')

print(features)
# Out:
# ['Duration', 'Src Pt', 'Dst Pt', 'Packets', 'Bytes', 'U', 'A', 'P', 'R', 'S', 'F', 'year', 'month', 'days', 'hours', 'minutes', 'seconds']

# %%
from sklearn.preprocessing import LabelEncoder
# Label Encoding our target variable column
le = LabelEncoder()
total_data['attackType'] = le.fit_transform(total_data['attackType'])

# %%
le_name_mapping = dict(zip(le.classes_, le.transform(le.classes_)))
print(le_name_mapping)
# Out:
# {'blasterWorm': 0, 'bruteForce': 1, 'dos': 2, 'fragmentation': 3, 'httpFlood': 4, 'icmpFlood': 5, 'landAttack': 6, 'pingScan': 7, 'portScan': 8, 'reaperWorm': 9, 'redWorm': 10, 'scanning': 11, 'smurf': 12, 'spam': 13, 'synFlood': 14, 'udpFlood': 15}

# %%
target = "attackType" # This is going to be a multiclass classification task

# %% [markdown]
# #### Since I will be using CatBoostClassifier first, we won't need to undergo any feature normalization of sorts as it is a tree based model.
# #### However, there are some articles and papers out there mentioning since this is a gradient boosting model, we would still need to normalize data. For now, I will just proceed on but would be a good attempt to try and normalize the data in the future and observe if there are any meaningful changes to the result.

# %% [markdown]
# # Splitting data up

# %%
class Split():
    
    def __init__(self, num = 5):  # num refers to the number of datasets you wanna split the original total dataset into
        self.total_data = total_data
        self.target = le.classes_.tolist()
        self._0 = []
        self._1 = []
        self._2 = []
        self._3 = []
        self._4 = []
        self._5 = []
        self._6 = []
        self._7 = []
        self._8 = []
        self._9 = []
        self._10 = []
        self._11 = []
        self._12 = []
        self._13 = []
        self._14 = []
        self._15 = []
        self._16 = []
        self.cv = num

    def generate(self):
        self._split()

        res = []
        
        for i in tqdm(range(self.cv)):
            if i != self.cv-1:
                tmp = self._0[i*(len(self._0)//self.cv):(i+1)*(len(self._0)//self.cv)] + self._1[i*(len(self._1)//self.cv):(i+1)*(len(self._1)//self.cv)] + self._2[i*(len(self._2)//self.cv):(i+1)*(len(self._2)//self.cv)] + self._3[i*(len(self._3)//self.cv):(i+1)*(len(self._3)//self.cv)] + self._4[i*(len(self._4)//self.cv):(i+1)*(len(self._4)//self.cv)] + self._5[i*(len(self._5)//self.cv):(i+1)*(len(self._5)//self.cv)] + self._6[i*(len(self._6)//self.cv):(i+1)*(len(self._6)//self.cv)] + self._7[i*(len(self._7)//self.cv):(i+1)*(len(self._7)//self.cv)] + self._8[i*(len(self._8)//self.cv):(i+1)*(len(self._8)//self.cv)] + self._9[i*(len(self._9)//self.cv):(i+1)*(len(self._9)//self.cv)] + self._10[i*(len(self._10)//self.cv):(i+1)*(len(self._10)//self.cv)] + self._11[i*(len(self._11)//self.cv):(i+1)*(len(self._11)//self.cv)] + self._12[i*(len(self._12)//self.cv):(i+1)*(len(self._12)//self.cv)] + self._13[i*(len(self._13)//self.cv):(i+1)*(len(self._13)//self.cv)] + self._14[i*(len(self._14)//self.cv):(i+1)*(len(self._14)//self.cv)] + self._15[i*(len(self._15)//self.cv):(i+1)*(len(self._15)//self.cv)] + self._16[i*(len(self._16)//self.cv):(i+1)*(len(self._16)//self.cv)]
            elif i == self.cv-1:
                tmp = self._0[i*(len(self._0)//self.cv):-1] + self._1[i*(len(self._1)//self.cv):-1] + self._2[i*(len(self._2)//self.cv):-1] + self._3[i*(len(self._3)//self.cv):-1] + self._4[i*(len(self._4)//self.cv):-1] + self._5[i*(len(self._5)//self.cv):-1] + self._6[i*(len(self._6)//self.cv):-1] + self._7[i*(len(self._7)//self.cv):-1] + self._8[i*(len(self._8)//self.cv):-1] + self._9[i*(len(self._9)//self.cv):-1] + self._10[i*(len(self._10)//self.cv):-1] + self._11[i*(len(self._11)//self.cv):-1] + self._12[i*(len(self._12)//self.cv):-1] + self._13[i*(len(self._13)//self.cv):-1] + self._14[i*(len(self._14)//self.cv):-1] + self._15[i*(len(self._15)//self.cv):-1] + self._16[i*(len(self._16)//self.cv):-1]
            res.append(tmp)

        return res # Returns arrays of indices
        
    def _split(self):
        length = len(self.total_data)
        print("Splitting...")
        for i in tqdm(range(length)):
            ttype = self.total_data.iloc[i].attackType
            match ttype:
                case 0:
                    self._0.append(i)
                case 1:
                    self._1.append(i)
                case 2:
                    self._2.append(i)
                case 3:
                    self._3.append(i)
                case 4:
                    self._4.append(i)
                case 5: 
                    self._5.append(i)
                case 6:
                    self._6.append(i)
                case 7:
                    self._7.append(i)
                case 8:
                    self._8.append(i)
                case 9:
                    self._9.append(i)
                case 10:
                    self._10.append(i)
                case 11:
                    self._11.append(i)
                case 12:
                    self._12.append(i)
                case 13:
                    self._13.append(i)
                case 14:
                    self._14.append(i)
                case 15:
                    self._15.append(i)
                case 16:
                    self._16.append(i)

        print("Splitting done!")

# %%
subset_count = 5
split = Split(num = subset_count) # num refers to the number of datasets you wanna split the original total dataset into
split_data = split.generate()
# Out:
# Splitting...
# 100%|██████████| 5939551/5939551 [03:01<00:00, 32652.82it/s]
# Splitting done!
# 100%|██████████| 5/5 [00:00<00:00, 24.14it/s]

# %% [markdown]
# # Model

# %%
from xgboost import XGBClassifier
from sklearn.linear_model import LogisticRegression
from catboost import CatBoostClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import roc_auc_score

# Take the models from here and insert it below

xgb = XGBClassifier(objective='multi:softprob',
                   enable_categorical=True)

cat = CatBoostClassifier(loss_function='MultiClass', # MultiClass, MultiClassOneVsAll
                         eval_metric =  'Accuracy', # AUC
                         verbose=10,
                         depth = 5,
                         early_stopping_rounds=10,
                         # cat_features=[1, 2, 4]
                        )

lr = LogisticRegression()

# %% [markdown]
# # Training

# %%
from sklearn.model_selection import StratifiedKFold
import time

# Training various different models for reliability (different random_seed)
models = [CatBoostClassifier(loss_function='MultiClass', # MultiClass, MultiClassOneVsAll
                             eval_metric =  'Accuracy', # AUC
                             verbose=10,
                             depth = 10,
                             early_stopping_rounds=10,
                             random_seed = 42,
                             # cat_features=[1, 2, 4]
                            ),
         CatBoostClassifier(loss_function='MultiClass', # MultiClass, MultiClassOneVsAll
                             eval_metric =  'Accuracy', # AUC
                             verbose=10,
                             depth = 10,
                             early_stopping_rounds=10,
                             random_seed = 32,
                             # cat_features=[1, 2, 4]
                            ),
         CatBoostClassifier(loss_function='MultiClass', # MultiClass, MultiClassOneVsAll
                             eval_metric =  'Accuracy', # AUC
                             verbose=10,
                             depth = 10,
                             early_stopping_rounds=10,
                             random_seed = 22,
                             # cat_features=[1, 2, 4]
                            ),
         CatBoostClassifier(loss_function='MultiClass', # MultiClass, MultiClassOneVsAll
                             eval_metric =  'Accuracy', # AUC
                             verbose=10,
                             depth = 10,
                             early_stopping_rounds=10,
                             random_seed = 12,
                             # cat_features=[1, 2, 4]
                            ),
         CatBoostClassifier(loss_function='MultiClass', # MultiClass, MultiClassOneVsAll
                             eval_metric =  'Accuracy', # AUC
                             verbose=10,
                             depth = 10,
                             early_stopping_rounds=10,
                             random_seed = 2,
                             # cat_features=[1, 2, 4]
                            )
         ]



# Batch Training out model
testing_subset_number = 4 # Which subset of the whole dataset you wish to test the models on. This index subset would be automatically removed from the training dataset
total_subset_arr = [i for i in range(subset_count)]
total_subset_arr.remove(testing_subset_number)

for subset in total_subset_arr: # Testing on the last subset
    print("Subset {}".format(subset+1))
    print("----------------------")
    
    # Obtaining our i-th subset of the total data
    X = total_data.iloc[split_data[subset]][features]
    y = total_data.iloc[split_data[subset]][target]
    
    # Applying StratifiedKFold to the specific subset
    skf = StratifiedKFold(n_splits=len(models))
    skf.get_n_splits(X, y)
    
    acc = []

    for i, (train_index, test_index) in enumerate(skf.split(X, y)):
        start_time = time.time()
        print(f"\nSubset - {subset+1} | Fold - {i+1}")
        print("----------------------")

        X_train, X_test = X.iloc[train_index], X.iloc[test_index]
        y_train, y_test = y.iloc[train_index], y.iloc[test_index]

        # Paste models here
        model = models[i]

        # Train
        if subset == 0:
            print("Training...")
            print("----------------------")
            model.fit(X_train, y_train, eval_set=(X_test, y_test))
        else:
            print("Training using saved model...")
            print("----------------------")
            model.fit(X_train, y_train, eval_set=(X_test, y_test), init_model='model_{}.cbm'.format(i)) # Batch Training
        model.save_model('model_{}.cbm'.format(i))
        print("Training done!")
        print("----------------------")

        # Predict
        pred = model.predict(X_test)
        accuracy = accuracy_score(y_test, pred)
        acc.append(accuracy)
        # auc = roc_auc_score(y_test, model.predict_proba(X_test)[:, 1], multi_class='ovr')

        # Printing
        print("Subset - {} | Fold - {} Accuracy: {:.2f}%".format(subset+1, i+1, accuracy*100))
        # print("AUC: {:.2f}".format(auc))
        print("Time taken: {:.0f}s".format(time.time()-start_time))
        print("----------------------")

    print("----------------------")
    print("Average accuracy: {:.2f}%".format(np.mean(acc)*100))
# Out:
# Subset 1
# ----------------------
#
# Subset - 1 | Fold - 1
# ----------------------
# Training...
# ----------------------
# Learning rate set to 0.123847
# 0:	learn: 0.9843159	test: 0.8534437	best: 0.8534437 (0)	total: 1.25s	remaining: 20m 52s
# 10:	learn: 0.9878178	test: 0.9862994	best: 0.9862994 (6)	total: 17.3s	remaining: 25m 56s
# 20:	learn: 0.9879178	test: 0.9866277	best: 0.9866277 (20)	total: 35.3s	remaining: 27m 27s
# 30:	learn: 0.9879915	test: 0.9877726	best: 0.9877726 (30)	total: 52s	remaining: 27m 6s
# 40:	learn: 0.9880051	test: 0.9877726	best: 0.9878231 (33)	total: 1m 10s	remaining: 27m 21s
# Stopped by overfitting detector  (10 iterations wait)
#
# bestTest = 0.9878231003
# bestIteration = 33
#
# Shrink model to first 34 iterations.
# Training done!
# ----------------------
# Subset - 1 | Fold - 1 Accuracy: 98.78%
# Time taken: 76s
# ----------------------
#
# Subset - 1 | Fold - 2
# ----------------------
# Training...
# ----------------------
# Learning rate set to 0.123847
# 0:	learn: 0.9871465	test: 0.8375754	best: 0.8375754 (0)	total: 2.02s	remaining: 33m 34s
# 10:	learn: 0.9876916	test: 0.9703091	best: 0.9703091 (10)	total: 18.7s	remaining: 28m
# 20:	learn: 0.9879767	test: 0.9712898	best: 0.9712898 (20)	total: 37.6s	remaining: 29m 12s
# 30:	learn: 0.9880115	test: 0.9716644	best: 0.9716644 (30)	total: 55.9s	remaining: 29m 7s
# 40:	learn: 0.9880230	test: 0.9772541	best: 0.9772541 (40)	total: 1m 13s	remaining: 28m 37s
# 50:	learn: 0.9880293	test: 0.9807139	best: 0.9807139 (50)	total: 1m 31s	remaining: 28m 24s
# 60:	learn: 0.9880283	test: 0.9825070	best: 0.9825070 (60)	total: 1m 49s	remaining: 28m 9s
# 70:	learn: 0.9880283	test: 0.9832268	best: 0.9832268 (70)	total: 2m 8s	remaining: 27m 55s
# 80:	learn: 0.9880304	test: 0.9850283	best: 0.9850283 (80)	total: 2m 26s	remaining: 27m 41s
# 90:	learn: 0.9880315	test: 0.9856723	best: 0.9856723 (90)	total: 2m 44s	remaining: 27m 24s
# 100:	learn: 0.9880336	test: 0.9857059	best: 0.9857059 (100)	total: 3m 4s	remaining: 27m 20s
# 110:	learn: 0.9880357	test: 0.9856849	best: 0.9857143 (101)	total: 3m 23s	remaining: 27m 11s
# Stopped by overfitting detector  (10 iterations wait)
#
# bestTest = 0.9857143458
# bestIteration = 101
#
# Shrink model to first 102 iterations.
# Training done!
# ----------------------
# Subset - 1 | Fold - 2 Accuracy: 98.57%
# Time taken: 206s
# ----------------------
#
# Subset - 1 | Fold - 3
# ----------------------
# Training...
# ----------------------
# Learning rate set to 0.123847
# 0:	learn: 0.9871233	test: 0.9868087	best: 0.9868087 (0)	total: 2.05s	remaining: 34m 4s
# 10:	learn: 0.9876337	test: 0.9875453	best: 0.9875453 (10)	total: 19s	remaining: 28m 25s
# 20:	learn: 0.9879673	test: 0.9879999	best: 0.9880083 (19)	total: 37.1s	remaining: 28m 49s
# 30:	learn: 0.9879841	test: 0.9880209	best: 0.9880209 (27)	total: 55.2s	remaining: 28m 44s
# 40:	learn: 0.9879999	test: 0.9880251	best: 0.9880251 (32)	total: 1m 17s	remaining: 30m 1s
# Stopped by overfitting detector  (10 iterations wait)
#
# bestTest = 0.9880251367
# bestIteration = 32
#
# Shrink model to first 33 iterations.
# Training done!
# ----------------------
# Subset - 1 | Fold - 3 Accuracy: 98.80%
# Time taken: 82s
# ----------------------
#
# Subset - 1 | Fold - 4
# ----------------------
# Training...
# ----------------------
# Learning rate set to 0.123847
# 0:	learn: 0.9857606	test: 0.9856091	best: 0.9856091 (0)	total: 1.86s	remaining: 30m 57s
# 10:	learn: 0.9876600	test: 0.9877473	best: 0.9877473 (6)	total: 19.1s	remaining: 28m 38s
# 20:	learn: 0.9879767	test: 0.9877600	best: 0.9877600 (16)	total: 37.4s	remaining: 29m 2s
# Stopped by overfitting detector  (10 iterations wait)
#
# bestTest = 0.987759964
# bestIteration = 16
#
# Shrink model to first 17 iterations.
# Training done!
# ----------------------
# Subset - 1 | Fold - 4 Accuracy: 98.78%
# Time taken: 47s
# ----------------------
#
# Subset - 1 | Fold - 5
# ----------------------
# Training...
# ----------------------
# Learning rate set to 0.123847
# 0:	learn: 0.9856165	test: 0.9863036	best: 0.9863036 (0)	total: 1.2s	remaining: 19m 58s
# 10:	learn: 0.9874538	test: 0.9876632	best: 0.9876632 (10)	total: 19.6s	remaining: 29m 20s
# 20:	learn: 0.9879830	test: 0.9867077	best: 0.9876800 (13)	total: 41.4s	remaining: 32m 8s
# Stopped by overfitting detector  (10 iterations wait)
#
# bestTest = 0.9876799912
# bestIteration = 13
#
# Shrink model to first 14 iterations.
# Training done!
# ----------------------
# Subset - 1 | Fold - 5 Accuracy: 98.77%
# Time taken: 48s
# ----------------------
# ----------------------
# Average accuracy: 98.74%
# Subset 2
# ----------------------
#
# Subset - 2 | Fold - 1
# ----------------------
# Training using saved model...
# ----------------------
# Learning rate set to 0.123847
# 0:	learn: 0.8850655	test: 0.9876042	best: 0.9876042 (0)	total: 2.12s	remaining: 35m 19s
# 10:	learn: 0.9879315	test: 0.9876253	best: 0.9876295 (4)	total: 21.8s	remaining: 32m 37s
# 20:	learn: 0.9879988	test: 0.9877095	best: 0.9877515 (18)	total: 42.9s	remaining: 33m 19s
# Stopped by overfitting detector  (10 iterations wait)
#
# bestTest = 0.9877515458
# bestIteration = 18
#
# Shrink model to first 19 iterations.
# Training done!
# ----------------------
# Subset - 2 | Fold - 1 Accuracy: 98.78%
# Time taken: 60s
# ----------------------
#
# Subset - 2 | Fold - 2
# ----------------------
# Training using saved model...
# ----------------------
# Learning rate set to 0.123847
# 0:	learn: 0.9080219	test: 0.8912834	best: 0.8912834 (0)	total: 1.89s	remaining: 31m 29s
# 10:	learn: 0.9878210	test: 0.9867708	best: 0.9867708 (10)	total: 23s	remaining: 34m 29s
# 20:	learn: 0.9880136	test: 0.9870107	best: 0.9870107 (17)	total: 43.5s	remaining: 33m 48s
# 30:	learn: 0.9880293	test: 0.9879452	best: 0.9879452 (28)	total: 1m 3s	remaining: 33m 14s
# 40:	learn: 0.9880346	test: 0.9879915	best: 0.9879915 (40)	total: 1m 23s	remaining: 32m 28s
# 50:	learn: 0.9880346	test: 0.9880083	best: 0.9880083 (42)	total: 1m 45s	remaining: 32m 35s
# Stopped by overfitting detector  (10 iterations wait)
#
# bestTest = 0.9880083003
# bestIteration = 42
#
# Shrink model to first 43 iterations.
# Training done!
# ----------------------
# Subset - 2 | Fold - 2 Accuracy: 98.80%
# Time taken: 110s
# ----------------------
#
# Subset - 2 | Fold - 3
# ----------------------
# Training using saved model...
# ----------------------
# Learning rate set to 0.123847
# 0:	learn: 0.8953746	test: 0.7404296	best: 0.7404296 (0)	total: 1.86s	remaining: 30m 58s
# 10:	learn: 0.9879599	test: 0.9879031	best: 0.9879031 (10)	total: 20.4s	remaining: 30m 31s
# 20:	learn: 0.9880020	test: 0.9879157	best: 0.9879157 (20)	total: 39s	remaining: 30m 16s
# 30:	learn: 0.9880293	test: 0.9879241	best: 0.9879241 (28)	total: 58.1s	remaining: 30m 15s
# Stopped by overfitting detector  (10 iterations wait)
#
# bestTest = 0.9879241185
# bestIteration = 28
#
# Shrink model to first 29 iterations.
# Training done!
# ----------------------
# Subset - 2 | Fold - 3 Accuracy: 98.79%
# Time taken: 76s
# ----------------------
#
# Subset - 2 | Fold - 4
# ----------------------
# Training using saved model...
# ----------------------
# Learning rate set to 0.123847
# 0:	learn: 0.8872574	test: 0.7787702	best: 0.7787702 (0)	total: 2.38s	remaining: 39m 37s
# 10:	learn: 0.9879473	test: 0.9875874	best: 0.9875874 (10)	total: 22.4s	remaining: 33m 36s
# 20:	learn: 0.9879936	test: 0.9878399	best: 0.9878399 (20)	total: 43.2s	remaining: 33m 32s
# 30:	learn: 0.9880083	test: 0.9879494	best: 0.9879494 (30)	total: 1m 5s	remaining: 34m
# 40:	learn: 0.9880241	test: 0.9879620	best: 0.9879788 (31)	total: 1m 26s	remaining: 33m 49s
# 50:	learn: 0.9880315	test: 0.9879999	best: 0.9879999 (49)	total: 1m 45s	remaining: 32m 46s
# Stopped by overfitting detector  (10 iterations wait)
#
# bestTest = 0.9879998821
# bestIteration = 49
#
# Shrink model to first 50 iterations.
# Training done!
# ----------------------
# Subset - 2 | Fold - 4 Accuracy: 98.80%
# Time taken: 123s
# ----------------------
#
# Subset - 2 | Fold - 5
# ----------------------
# Training using saved model...
# ----------------------
# Learning rate set to 0.123847
# 0:	learn: 0.9523405	test: 0.7809800	best: 0.7809800 (0)	total: 1.87s	remaining: 31m 9s
# 10:	learn: 0.9879609	test: 0.6645355	best: 0.7825457 (4)	total: 20.9s	remaining: 31m 22s
# Stopped by overfitting detector  (10 iterations wait)
#
# bestTest = 0.7825457423
# bestIteration = 4
#
# Shrink model to first 5 iterations.
# Training done!
# ----------------------
# Subset - 2 | Fold - 5 Accuracy: 78.25%
# Time taken: 29s
# ----------------------
# ----------------------
# Average accuracy: 94.68%
# Subset 3
# ----------------------
#
# Subset - 3 | Fold - 1
# ----------------------
# Training using saved model...
# ----------------------
# Learning rate set to 0.123847
# 0:	learn: 0.9570946	test: 0.9767195	best: 0.9767195 (0)	total: 1.92s	remaining: 31m 59s
# 10:	learn: 0.9878473	test: 0.9827638	best: 0.9827638 (10)	total: 21s	remaining: 31m 31s
# 20:	learn: 0.9880125	test: 0.9846579	best: 0.9846579 (20)	total: 39.8s	remaining: 30m 57s
# 30:	learn: 0.9880167	test: 0.9847336	best: 0.9847336 (26)	total: 58.4s	remaining: 30m 24s
# 40:	learn: 0.9880230	test: 0.9847294	best: 0.9847378 (31)	total: 1m 18s	remaining: 30m 33s
# Stopped by overfitting detector  (10 iterations wait)
#
# bestTest = 0.9847378368
# bestIteration = 31
#
# Shrink model to first 32 iterations.
# Training done!
# ----------------------
# Subset - 3 | Fold - 1 Accuracy: 98.47%
# Time taken: 81s
# ----------------------
#
# Subset - 3 | Fold - 2
# ----------------------
# Training using saved model...
# ----------------------
# Learning rate set to 0.123847
# 0:	learn: 0.9792818	test: 0.9772793	best: 0.9772793 (0)	total: 2.14s	remaining: 35m 41s
# 10:	learn: 0.9877905	test: 0.9878736	best: 0.9878736 (10)	total: 22.9s	remaining: 34m 20s
# 20:	learn: 0.9879683	test: 0.9879410	best: 0.9879410 (20)	total: 45.6s	remaining: 35m 26s
# 30:	learn: 0.9879946	test: 0.9879452	best: 0.9879620 (26)	total: 1m 7s	remaining: 35m 14s
# Stopped by overfitting detector  (10 iterations wait)
#
# bestTest = 0.9879620003
# bestIteration = 26
#
# Shrink model to first 27 iterations.
# Training done!
# ----------------------
# Subset - 3 | Fold - 2 Accuracy: 98.80%
# Time taken: 82s
# ----------------------
#
# Subset - 3 | Fold - 3
# ----------------------
# Training using saved model...
# ----------------------
# Learning rate set to 0.123847
# 0:	learn: 0.9722663	test: 0.9566716	best: 0.9566716 (0)	total: 2.43s	remaining: 40m 28s
# 10:	learn: 0.9876105	test: 0.9846873	best: 0.9846873 (10)	total: 23.7s	remaining: 35m 34s
# 20:	learn: 0.9879746	test: 0.9848515	best: 0.9848515 (18)	total: 44.2s	remaining: 34m 18s
# 30:	learn: 0.9880083	test: 0.9850451	best: 0.9850535 (29)	total: 1m 5s	remaining: 33m 57s
# 40:	learn: 0.9880220	test: 0.9852556	best: 0.9852556 (40)	total: 1m 25s	remaining: 33m 14s
# 50:	learn: 0.9880293	test: 0.9855418	best: 0.9856007 (49)	total: 1m 44s	remaining: 32m 29s
# 60:	learn: 0.9880357	test: 0.9856680	best: 0.9856680 (60)	total: 2m 4s	remaining: 31m 56s
# 70:	learn: 0.9880357	test: 0.9856849	best: 0.9856975 (64)	total: 2m 24s	remaining: 31m 32s
# 80:	learn: 0.9880357	test: 0.9857606	best: 0.9857817 (79)	total: 2m 46s	remaining: 31m 26s
# 90:	learn: 0.9880357	test: 0.9858069	best: 0.9858154 (89)	total: 3m 9s	remaining: 31m 31s
# 100:	learn: 0.9880378	test: 0.9857901	best: 0.9858238 (91)	total: 3m 33s	remaining: 31m 42s
# Stopped by overfitting detector  (10 iterations wait)
#
# bestTest = 0.9858237822
# bestIteration = 91
#
# Shrink model to first 92 iterations.
# Training done!
# ----------------------
# Subset - 3 | Fold - 3 Accuracy: 98.58%
# Time taken: 217s
# ----------------------
#
# Subset - 3 | Fold - 4
# ----------------------
# Training using saved model...
# ----------------------
# Learning rate set to 0.123847
# 0:	learn: 0.9716760	test: 0.9483250	best: 0.9483250 (0)	total: 2.23s	remaining: 37m 4s
# 10:	learn: 0.9879862	test: 0.9552363	best: 0.9552363 (10)	total: 23.3s	remaining: 34m 54s
# 20:	learn: 0.9880209	test: 0.9583931	best: 0.9583931 (20)	total: 43.5s	remaining: 33m 50s
# 30:	learn: 0.9880262	test: 0.9627832	best: 0.9627832 (30)	total: 1m 4s	remaining: 33m 28s
# 40:	learn: 0.9880357	test: 0.9721021	best: 0.9721021 (40)	total: 1m 25s	remaining: 33m 14s
# 50:	learn: 0.9880388	test: 0.9798048	best: 0.9798048 (50)	total: 1m 45s	remaining: 32m 49s
# 60:	learn: 0.9880399	test: 0.9812232	best: 0.9812232 (60)	total: 2m 7s	remaining: 32m 36s
# 70:	learn: 0.9880399	test: 0.9814337	best: 0.9814337 (70)	total: 2m 28s	remaining: 32m 27s
# 80:	learn: 0.9880399	test: 0.9815010	best: 0.9815010 (80)	total: 2m 57s	remaining: 33m 39s
# 90:	learn: 0.9880399	test: 0.9814674	best: 0.9815137 (82)	total: 3m 21s	remaining: 33m 29s
# Stopped by overfitting detector  (10 iterations wait)
#
# bestTest = 0.9815136732
# bestIteration = 82
#
# Shrink model to first 83 iterations.
# Training done!
# ----------------------
# Subset - 3 | Fold - 4 Accuracy: 98.15%
# Time taken: 206s
# ----------------------
#
# Subset - 3 | Fold - 5
# ----------------------
# Training using saved model...
# ----------------------
# Learning rate set to 0.123847
# 0:	learn: 0.9837645	test: 0.9735795	best: 0.9735795 (0)	total: 2.21s	remaining: 36m 52s
# 10:	learn: 0.9879473	test: 0.9877347	best: 0.9877347 (9)	total: 24.1s	remaining: 36m 4s
# 20:	learn: 0.9879904	test: 0.9877558	best: 0.9877642 (17)	total: 45.8s	remaining: 35m 37s
# 30:	learn: 0.9880146	test: 0.9877726	best: 0.9877768 (26)	total: 1m 5s	remaining: 34m 1s
# Stopped by overfitting detector  (10 iterations wait)
#
# bestTest = 0.9877768003
# bestIteration = 26
#
# Shrink model to first 27 iterations.
# Training done!
# ----------------------
# Subset - 3 | Fold - 5 Accuracy: 98.78%
# Time taken: 78s
# ----------------------
# ----------------------
# Average accuracy: 98.56%
# Subset 4
# ----------------------
#
# Subset - 4 | Fold - 1
# ----------------------
# Training using saved model...
# ----------------------
# Learning rate set to 0.123847
# 0:	learn: 0.9850440	test: 0.9880041	best: 0.9880041 (0)	total: 1.95s	remaining: 32m 28s
# 10:	learn: 0.9879199	test: 0.9879873	best: 0.9880041 (0)	total: 22.8s	remaining: 34m 9s
# Stopped by overfitting detector  (10 iterations wait)
#
# bestTest = 0.9880040912
# bestIteration = 0
#
# Shrink model to first 1 iterations.
# Training done!
# ----------------------
# Subset - 4 | Fold - 1 Accuracy: 98.80%
# Time taken: 24s
# ----------------------
#
# Subset - 4 | Fold - 2
# ----------------------
# Training using saved model...
# ----------------------
# Learning rate set to 0.123847
# 0:	learn: 0.9861447	test: 0.9850114	best: 0.9850114 (0)	total: 3.32s	remaining: 55m 16s
# 10:	learn: 0.9878820	test: 0.9869434	best: 0.9869434 (10)	total: 25.9s	remaining: 38m 45s
# 20:	learn: 0.9880262	test: 0.9875453	best: 0.9875453 (20)	total: 47.1s	remaining: 36m 33s
# 30:	learn: 0.9880378	test: 0.9879915	best: 0.9879915 (30)	total: 1m 9s	remaining: 35m 59s
# 40:	learn: 0.9880388	test: 0.9880083	best: 0.9880083 (32)	total: 1m 31s	remaining: 35m 31s
# Stopped by overfitting detector  (10 iterations wait)
#
# bestTest = 0.9880083003
# bestIteration = 32
#
# Shrink model to first 33 iterations.
# Training done!
# ----------------------
# Subset - 4 | Fold - 2 Accuracy: 98.80%
# Time taken: 97s
# ----------------------
#
# Subset - 4 | Fold - 3
# ----------------------
# Training using saved model...
# ----------------------
# Learning rate set to 0.123847
# 0:	learn: 0.9865267	test: 0.9871496	best: 0.9871496 (0)	total: 2.02s	remaining: 33m 42s
# 10:	learn: 0.9878589	test: 0.9878652	best: 0.9878652 (10)	total: 23.4s	remaining: 35m
# 20:	learn: 0.9880125	test: 0.9879325	best: 0.9879325 (16)	total: 44.3s	remaining: 34m 24s
# 30:	learn: 0.9880209	test: 0.9879494	best: 0.9879494 (30)	total: 1m 5s	remaining: 33m 52s
# 40:	learn: 0.9880283	test: 0.9879578	best: 0.9879620 (36)	total: 1m 25s	remaining: 33m 9s
# 50:	learn: 0.9880325	test: 0.9879704	best: 0.9879704 (45)	total: 1m 45s	remaining: 32m 37s
# Stopped by overfitting detector  (10 iterations wait)
#
# bestTest = 0.9879704185
# bestIteration = 45
#
# Shrink model to first 46 iterations.
# Training done!
# ----------------------
# Subset - 4 | Fold - 3 Accuracy: 98.80%
# Time taken: 116s
# ----------------------
#
# Subset - 4 | Fold - 4
# ----------------------
# Training using saved model...
# ----------------------
# Learning rate set to 0.123847
# 0:	learn: 0.9861237	test: 0.9845526	best: 0.9845526 (0)	total: 2.14s	remaining: 35m 38s
# 10:	learn: 0.9878515	test: 0.9873643	best: 0.9873643 (10)	total: 23.5s	remaining: 35m 9s
# 20:	learn: 0.9880125	test: 0.9877768	best: 0.9877768 (20)	total: 43.9s	remaining: 34m 8s
# 30:	learn: 0.9880346	test: 0.9879031	best: 0.9879031 (30)	total: 1m 3s	remaining: 33m 3s
# 40:	learn: 0.9880378	test: 0.9879746	best: 0.9879746 (39)	total: 1m 23s	remaining: 32m 34s
# 50:	learn: 0.9880388	test: 0.9879873	best: 0.9879873 (47)	total: 1m 42s	remaining: 31m 54s
# 60:	learn: 0.9880399	test: 0.9879957	best: 0.9879957 (60)	total: 2m 3s	remaining: 31m 37s
# 70:	learn: 0.9880399	test: 0.9880083	best: 0.9880083 (66)	total: 2m 23s	remaining: 31m 17s
# Stopped by overfitting detector  (10 iterations wait)
#
# bestTest = 0.9880083003
# bestIteration = 66
#
# Shrink model to first 67 iterations.
# Training done!
# ----------------------
# Subset - 4 | Fold - 4 Accuracy: 98.80%
# Time taken: 157s
# ----------------------
#
# Subset - 4 | Fold - 5
# ----------------------
# Training using saved model...
# ----------------------
# Learning rate set to 0.123847
# 0:	learn: 0.9866667	test: 0.9841738	best: 0.9841738 (0)	total: 2.01s	remaining: 33m 28s
# 10:	learn: 0.9879462	test: 0.9845274	best: 0.9845274 (10)	total: 22.5s	remaining: 33m 41s
# 20:	learn: 0.9880178	test: 0.9834330	best: 0.9845358 (11)	total: 42s	remaining: 32m 37s
# Stopped by overfitting detector  (10 iterations wait)
#
# bestTest = 0.9845358004
# bestIteration = 11
#
# Shrink model to first 12 iterations.
# Training done!
# ----------------------
# Subset - 4 | Fold - 5 Accuracy: 98.45%
# Time taken: 45s
# ----------------------
# ----------------------
# Average accuracy: 98.73%

# %% [markdown]
# # Testing on a different subset of dataset (never seen before by the model)

# %%
total_acc = []

X_new = total_data.iloc[split_data[testing_subset_number]][features]
y_new = total_data.iloc[split_data[testing_subset_number]][target]
acc = []
    
for model in models:
    pred_new = model.predict(X_new)
    accuracy_new = accuracy_score(y_new, pred_new)
    acc.append(accuracy_new)

total_acc.append(np.mean(acc))

print("Total accuracy over the other subsets of the total data: {:.2f}%".format(np.mean(total_acc)*100))
# Out:
# Total accuracy over the other subsets of the total data: 87.51%
