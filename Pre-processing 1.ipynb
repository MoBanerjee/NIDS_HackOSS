# %%
# importing pandas library
import pandas as pd

# %%
# importing numpy library
import numpy as np

# %%
import warnings

# Ignore all warnings
warnings.filterwarnings("ignore")

# %%
# adding headers
header_orig = ["ID","ts_year","ts_month","ts_day","ts_hour","ts_min","ts_second","te_year","te_month",
          "te_day","te_hour","te_min","te_second","duration","Src IP Addr","Dst IP Addr","Src Port","Dst Port","Protocol","_flag1","_flag2",
          "_flag3","_flag4","_flag5","_flag6","fwd","stos","Packets","Bytes","opkt","obyt","_in","out",
          "sas","das","smk","dmk","dtos","_dir","nh","nhb","svln","dvln","ismc","odmc","idmc","osmc",
          "mpls1","mpls2","mpls3","mpls4","mpls5","mpls6","mpls7","mpls8","mpls9","mpls10","cl","sl",
          "al","ra","eng","exid","tr","icmp_dst_ip_b","icmp_src_ip","udp_dst_p","tcp_f_s","tcp_f_n_a",
          "tcp_f_n_f","tcp_f_n_r","tcp_f_n_p","tcp_f_n_u","tcp_dst_p","tcp_src_dst_f_s","tcp_src_tftp",
          "tcp_src_kerb","tcp_src_rpc","tcp_dst_p_src","smtp_dst","udp_p_r_range","p_range_dst",
          "udp_src_p_0","class","attack_a"]

# %%
# reading blaster_worm files
blaster_worm = pd.read_csv('BLASTER_WORM_v2.csv',names=header_orig)

# sampling 58000 rows 
blaster_worm_sample = blaster_worm.sample(58000)
blaster_worm_sample['attack_name'] = 'Blaster Worm'

# deleting the baster_worm dataset to save space
del blaster_worm
# %reset -f blaster_worm
# Out:
# Don't know how to reset  blaster_worm, please run `%reset?` for details

# %%
# reading fragmentation csv
fragmentation = pd.read_csv('FRAGMENTATION_v2.csv',names=header_orig)
fragmentation_sample = fragmentation.sample(58000)
fragmentation_sample['attack_name'] = 'Fragmentation'

# deleting to save space
del fragmentation 
# %reset -f fragmentation
# Out:
# Don't know how to reset  fragmentation, please run `%reset?` for details

# %%
http_flood = pd.read_csv('HTTP_FLOOD_v2.csv',names = header_orig)

http_flood_sample = http_flood.sample(58000)
http_flood_sample['attack_name'] = 'HTTP Flood'

del http_flood
# %reset -f http_flood
# Out:
# Don't know how to reset  http_flood, please run `%reset?` for details

# %%
icmp_flood = pd.read_csv('ICMP_FLOOD_v2.csv',names=header_orig)

icmp_flood_sample = icmp_flood.sample(58000)
icmp_flood_sample['attack_name']='ICMP Flood'

del icmp_flood
# %reset -f icmp_flood
# Out:
# Don't know how to reset  icmp_flood, please run `%reset?` for details

# %%
reaper_flood = pd.read_csv('REAPER_WORM_v2.csv',names = header_orig)

reaper_flood_sample = reaper_flood.sample(58000)
reaper_flood_sample['attack_name']='Reaper Flood'

del reaper_flood
# %reset -f reaper_flood
# Out:
# Don't know how to reset  reaper_flood, please run `%reset?` for details

# %%
red_worm = pd.read_csv('RED_WORM_v2.csv',names=header_orig)

red_worm_sample = red_worm.sample(58000)
red_worm_sample['attack_name'] = 'Red Worm'

del red_worm
# %reset -f red_worm
# Out:
# Don't know how to reset  red_worm, please run `%reset?` for details

# %%
udp_flood = pd.read_csv('UDP_FLOOD_v2.csv',names=header_orig)

udp_flood_sample = udp_flood.sample(58000)
udp_flood_sample['attack_name'] = 'UDP Flood'

del udp_flood
# %reset -f udp_flood
# Out:
# Don't know how to reset  udp_flood, please run `%reset?` for details

# %%
def tcp_flags(elem):
    if elem in ("U", "A", "P", "R", "S", "F"):  #flag is set
        return 1
    else:
        return 0

# U --> urgent 
# A --> Acknowledgment 
# P --> Push
# R --> Reset
# S --> Synchronise
# F --> Finish

# %%
def modifying_dataset(df):
    # only extracting the necessary columns 
    df = df[['ts_year', 'ts_month', 'ts_day', 'ts_hour', 'ts_min',
       'ts_second', 'te_year', 'te_month', 'te_day', 'te_hour', 'te_min',
       'te_second','duration',"Src IP Addr","Dst IP Addr","Src Port","Dst Port","Protocol","_flag1","_flag2",
          "_flag3","_flag4","_flag5","_flag6",'class','attack_name']]
    
    # one hot encoding the flags and renaming to U,A,P,R,S,F for better understanding
    flags_df = df[["_flag1", "_flag2", "_flag3", "_flag4", "_flag5", "_flag6"]]
    df[["_flag1", "_flag2", "_flag3", "_flag4", "_flag5", "_flag6"]] = flags_df.applymap(tcp_flags)
    column_mapping = {'_flag1':'U','_flag2':'A','_flag3':'P','_flag4':'R','_flag5':'S','_flag6':'F'}
    df.rename(columns = column_mapping, inplace = True)
    
    # changing class values to none and victim
    df['class'] = np.where(df['class'] != 'none', 'victim', df['class'])
    return df

# %% [markdown]
# Guide to what each column name means
# 1. ts_year, ts_month, ts_day - the date on which the attack started
# 2. ts_hour, ts_min, ts_second - the time at which the attack started
# 3. te_year, te_month, te_day - the date on which the attack ended
# 4. te_hour, te_min, te_second - the time at which the attack ended
# 5. duration - the time the attack lasted for
# 6. Src IP Addr, Dst IP Addr - the source and destination ip address respectively
# 7. Src Port, Dst Port - the source and destination port address respectively
# 8. Protocol - protocol of the network connection (ex- TCP, UDP, ICMP etc)
# 9. _ flags are renamed to U, A, P, R, S, F
# 10. class - attack or no
# 11. attack_name - name of the attack

# %%
modifying_dataset(blaster_worm_sample)
# Out:
#          ts_year  ts_month  ts_day  ts_hour  ts_min  ts_second  te_year  \
# 1663459     2020         1      25        3      46          9     2020
# 439870      2020         1      25        3      44         28     2020
# 191799      2020         1      25        3      44         11     2020
# 3028880     2020         1      25        3      48         41     2020
# 1230614     2020         1      25        3      46         33     2020
# ...          ...       ...     ...      ...     ...        ...      ...
# 442850      2020         1      25        3      44         29     2020
# 1090274     2020         1      25        3      45         20     2020
# 774366      2020         1      25        3      44         55     2020
# 94346       2020         1      25        3      44          5     2020
# 758772      2020         1      25        3      44         53     2020
#
#          te_month  te_day  te_hour  ...  Dst Port  Protocol  U  A  P  R  S  F  \
# 1663459         1      25        3  ...      3340       TCP  0  0  0  0  1  0
# 439870          1      25        3  ...      8000       TCP  0  0  0  0  1  0
# 191799          1      25        3  ...       666       TCP  0  0  0  0  1  0
# 3028880         1      25        3  ...      3181       TCP  0  0  0  0  1  0
# 1230614         1      25        3  ...     49184       TCP  0  1  0  0  1  1
# ...           ...     ...      ...  ...       ...       ... .. .. .. .. .. ..
# 442850          1      25        3  ...     18799       UDP  0  0  0  0  0  0
# 1090274         1      25        3  ...     30000       TCP  0  0  0  0  1  0
# 774366          1      25        3  ...      4444       TCP  0  0  0  0  1  0
# 94346           1      25        3  ...       111       TCP  0  0  0  0  1  0
# 758772          1      25        3  ...        23       TCP  0  0  0  0  1  0
#
#           class   attack_name
# 1663459    none  Blaster Worm
# 439870     none  Blaster Worm
# 191799     none  Blaster Worm
# 3028880    none  Blaster Worm
# 1230614    none  Blaster Worm
# ...         ...           ...
# 442850     none  Blaster Worm
# 1090274    none  Blaster Worm
# 774366   victim  Blaster Worm
# 94346      none  Blaster Worm
# 758772     none  Blaster Worm
#
# [58000 rows x 26 columns]

# %%
modifying_dataset(fragmentation_sample)
# Out:
#          ts_year  ts_month  ts_day  ts_hour  ts_min  ts_second  te_year  \
# 972027      2019        11      15        5      12         39     2019
# 433433      2019        11      15        5      10         39     2019
# 339843      2019        11      15        5      10         17     2019
# 1210236     2019        11      15        5      13         33     2019
# 1225356     2019        11      15        5      13         36     2019
# ...          ...       ...     ...      ...     ...        ...      ...
# 868113      2019        11      15        5      12         15     2019
# 659595      2019        11      15        5      11         29     2019
# 927307      2019        11      15        5      12         30     2019
# 961263      2019        11      15        5      12         37     2019
# 70169       2019        11      15        5       9         16     2019
#
#          te_month  te_day  te_hour  ...  Dst Port  Protocol  U  A  P  R  S  F  \
# 972027         11      15        5  ...         0      ICMP  0  0  0  0  0  0
# 433433         11      15        5  ...     33264       TCP  0  0  0  0  1  0
# 339843         11      15        5  ...        53       UDP  0  0  0  0  0  0
# 1210236        11      15        5  ...      1254       TCP  0  1  0  0  0  0
# 1225356        11      15        5  ...       443       TCP  0  1  0  0  0  0
# ...           ...     ...      ...  ...       ...       ... .. .. .. .. .. ..
# 868113         11      15        5  ...      3478       UDP  0  0  0  0  0  0
# 659595         11      15        5  ...     52286       TCP  0  1  1  0  0  0
# 927307         11      15        5  ...      3790       TCP  0  0  0  0  1  0
# 961263         11      15        5  ...     58540       TCP  0  1  1  0  0  0
# 70169          11      15        5  ...       123       UDP  0  0  0  0  0  0
#
#          class    attack_name
# 972027    none  Fragmentation
# 433433    none  Fragmentation
# 339843    none  Fragmentation
# 1210236   none  Fragmentation
# 1225356   none  Fragmentation
# ...        ...            ...
# 868113    none  Fragmentation
# 659595    none  Fragmentation
# 927307    none  Fragmentation
# 961263    none  Fragmentation
# 70169     none  Fragmentation
#
# [58000 rows x 26 columns]

# %%
modifying_dataset(http_flood_sample)
# Out:
#          ts_year  ts_month  ts_day  ts_hour  ts_min  ts_second  te_year  \
# 3993398     2020         1      16        9      33         48     2020
# 1030769     2020         1      16        9      30         12     2020
# 2029068     2020         1      16        9      31         26     2020
# 2145720     2020         1      16        9      31         33     2020
# 3943438     2020         1      16        9      33         44     2020
# ...          ...       ...     ...      ...     ...        ...      ...
# 4004125     2020         1      16        9      33         50     2020
# 670111      2020         1      16        9      29         46     2020
# 403184      2020         1      16        9      29         26     2020
# 2225440     2020         1      16        9      31         39     2020
# 683442      2020         1      16        9      29         48     2020
#
#          te_month  te_day  te_hour  ...  Dst Port  Protocol  U  A  P  R  S  F  \
# 3993398         1      16        9  ...     40441       TCP  0  1  0  0  0  0
# 1030769         1      16        9  ...       778      ICMP  0  0  0  0  0  0
# 2029068         1      16        9  ...     41345       TCP  0  1  1  0  0  0
# 2145720         1      16        9  ...     50983       TCP  0  1  1  0  0  0
# 3943438         1      16        9  ...       768      ICMP  0  0  0  0  0  0
# ...           ...     ...      ...  ...       ...       ... .. .. .. .. .. ..
# 4004125         1      16        9  ...       443       TCP  0  1  0  0  0  0
# 670111          1      16        9  ...       771      ICMP  0  0  0  0  0  0
# 403184          1      16        9  ...        53       UDP  0  0  0  0  0  0
# 2225440         1      16        9  ...     40916       TCP  0  1  0  0  1  0
# 683442          1      16        9  ...       443       TCP  0  1  1  0  0  0
#
#          class  attack_name
# 3993398   none   HTTP Flood
# 1030769   none   HTTP Flood
# 2029068   none   HTTP Flood
# 2145720   none   HTTP Flood
# 3943438   none   HTTP Flood
# ...        ...          ...
# 4004125   none   HTTP Flood
# 670111    none   HTTP Flood
# 403184    none   HTTP Flood
# 2225440   none   HTTP Flood
# 683442    none   HTTP Flood
#
# [58000 rows x 26 columns]

# %%
modifying_dataset(icmp_flood_sample)
# Out:
#          ts_year  ts_month  ts_day  ts_hour  ts_min  ts_second  te_year  \
# 1858484     2020         1      31       15      36         48     2020
# 1056653     2020         1      31       15      35         57     2020
# 3533961     2020         1      31       15      38         52     2020
# 2397942     2020         1      31       15      37         29     2020
# 2168891     2020         1      31       15      37         14     2020
# ...          ...       ...     ...      ...     ...        ...      ...
# 1832506     2020         1      31       15      36         46     2020
# 1420491     2020         1      31       15      36         19     2020
# 3980517     2020         1      31       15      39         20     2020
# 1966220     2020         1      31       15      36         57     2020
# 3343203     2020         1      31       15      38         39     2020
#
#          te_month  te_day  te_hour  ...  Dst Port  Protocol  U  A  P  R  S  F  \
# 1858484         1      31       15  ...     34962       UDP  0  0  0  0  0  0
# 1056653         1      31       15  ...     49764       UDP  0  0  0  0  0  0
# 3533961         1      31       15  ...     42090       TCP  0  0  0  0  0  0
# 2397942         1      31       15  ...      8619       UDP  0  0  0  0  0  0
# 2168891         1      31       15  ...        53       UDP  0  0  0  0  0  0
# ...           ...     ...      ...  ...       ...       ... .. .. .. .. .. ..
# 1832506         1      31       15  ...       443       TCP  0  0  0  0  0  0
# 1420491         1      31       15  ...      4903       TCP  0  0  0  0  0  0
# 3980517         1      31       15  ...     38298       UDP  0  0  0  0  0  0
# 1966220         1      31       15  ...     20519       UDP  0  0  0  0  0  0
# 3343203         1      31       15  ...        80       TCP  0  0  0  0  0  0
#
#          class  attack_name
# 1858484   none   ICMP Flood
# 1056653   none   ICMP Flood
# 3533961   none   ICMP Flood
# 2397942   none   ICMP Flood
# 2168891   none   ICMP Flood
# ...        ...          ...
# 1832506   none   ICMP Flood
# 1420491   none   ICMP Flood
# 3980517   none   ICMP Flood
# 1966220   none   ICMP Flood
# 3343203   none   ICMP Flood
#
# [58000 rows x 26 columns]

# %%
modifying_dataset(reaper_flood_sample)
# Out:
#          ts_year  ts_month  ts_day  ts_hour  ts_min  ts_second  te_year  \
# 4056652     2019        10       2        7      53         13     2019
# 4142579     2019        10       2        7      53         18     2019
# 2091688     2019        10       2        7      51          9     2019
# 4371898     2019        10       2        7      53         31     2019
# 1170216     2019        10       2        7      50         10     2019
# ...          ...       ...     ...      ...     ...        ...      ...
# 1415962     2019        10       2        7      50         23     2019
# 2030011     2019        10       2        7      51          4     2019
# 1517191     2019        10       2        7      50         31     2019
# 3438444     2019        10       2        7      52         33     2019
# 2661212     2019        10       2        7      51         44     2019
#
#          te_month  te_day  te_hour  ...  Dst Port  Protocol  U  A  P  R  S  F  \
# 4056652        10       2        7  ...     53695       TCP  0  0  0  0  1  0
# 4142579        10       2        7  ...     12106       UDP  0  0  0  0  0  0
# 2091688        10       2        7  ...     50011       TCP  0  1  1  0  0  0
# 4371898        10       2        7  ...     63763       TCP  0  1  1  0  0  0
# 1170216        10       2        7  ...     49174       TCP  0  1  0  1  1  0
# ...           ...     ...      ...  ...       ...       ... .. .. .. .. .. ..
# 1415962        10       2        7  ...     52755       UDP  0  0  0  0  0  0
# 2030011        10       2        7  ...       443       TCP  0  1  1  0  0  0
# 1517191        10       2        7  ...     34567       TCP  0  0  0  0  1  0
# 3438444        10       2        7  ...       443       TCP  0  1  1  0  1  0
# 2661212        10       2        7  ...        53       UDP  0  0  0  0  0  0
#
#          class   attack_name
# 4056652   none  Reaper Flood
# 4142579   none  Reaper Flood
# 2091688   none  Reaper Flood
# 4371898   none  Reaper Flood
# 1170216   none  Reaper Flood
# ...        ...           ...
# 1415962   none  Reaper Flood
# 2030011   none  Reaper Flood
# 1517191   none  Reaper Flood
# 3438444   none  Reaper Flood
# 2661212   none  Reaper Flood
#
# [58000 rows x 26 columns]

# %%
modifying_dataset(red_worm_sample)
# Out:
#          ts_year  ts_month  ts_day  ts_hour  ts_min  ts_second  te_year  \
# 1390139     2020         1      30       20      32         25     2020
# 1141414     2020         1      30       20      32         11     2020
# 1555986     2020         1      30       20      32         33     2020
# 3165691     2020         1      30       20      34          3     2020
# 607952      2020         1      30       20      31         41     2020
# ...          ...       ...     ...      ...     ...        ...      ...
# 4212101     2020         1      30       20      34         59     2020
# 683106      2020         1      30       20      31         47     2020
# 2844267     2020         1      30       20      33         44     2020
# 4073643     2020         1      30       20      34         53     2020
# 5054178     2020         1      30       20      35         46     2020
#
#          te_month  te_day  te_hour  ...  Dst Port  Protocol  U  A  P  R  S  F  \
# 1390139         1      30       20  ...     45284       TCP  0  1  0  0  1  0
# 1141414         1      30       20  ...     21073       TCP  0  1  0  0  1  0
# 1555986         1      30       20  ...     24471       TCP  0  1  0  0  1  0
# 3165691         1      30       20  ...     47295       TCP  0  1  0  0  1  0
# 607952          1      30       20  ...     46822       TCP  0  1  0  0  1  0
# ...           ...     ...      ...  ...       ...       ... .. .. .. .. .. ..
# 4212101         1      30       20  ...     53908       TCP  0  1  0  0  1  0
# 683106          1      30       20  ...     13788       TCP  0  1  0  0  1  0
# 2844267         1      30       20  ...     29892       TCP  0  1  0  0  1  0
# 4073643         1      30       20  ...     30827       TCP  0  1  0  0  1  0
# 5054178         1      30       20  ...     27449       TCP  0  1  0  0  1  0
#
#           class  attack_name
# 1390139    none     Red Worm
# 1141414    none     Red Worm
# 1555986  victim     Red Worm
# 3165691    none     Red Worm
# 607952     none     Red Worm
# ...         ...          ...
# 4212101  victim     Red Worm
# 683106   victim     Red Worm
# 2844267    none     Red Worm
# 4073643    none     Red Worm
# 5054178    none     Red Worm
#
# [58000 rows x 26 columns]

# %%
modifying_dataset(udp_flood_sample)
# Out:
#         ts_year  ts_month  ts_day  ts_hour  ts_min  ts_second  te_year  \
# 433551     2019         3       6       21      17         26     2019
# 549093     2019         3       6       21      18         19     2019
# 158156     2019         3       6       21      15         14     2019
# 316834     2019         3       6       21      16         30     2019
# 260764     2019         3       6       21      16          2     2019
# ...         ...       ...     ...      ...     ...        ...      ...
# 363151     2019         3       6       21      16         50     2019
# 471688     2019         3       6       21      17         43     2019
# 367903     2019         3       6       21      16         53     2019
# 127400     2019         3       6       21      15          1     2019
# 556608     2019         3       6       21      18         22     2019
#
#         te_month  te_day  te_hour  ...  Dst Port  Protocol  U  A  P  R  S  F  \
# 433551         3       6       21  ...        53       UDP  0  0  0  0  0  0
# 549093         3       6       21  ...        53       UDP  0  0  0  0  0  0
# 158156         3       6       21  ...     59316       UDP  0  0  0  0  0  0
# 316834         3       6       21  ...        53       UDP  0  0  0  0  0  0
# 260764         3       6       21  ...        53       UDP  0  0  0  0  0  0
# ...          ...     ...      ...  ...       ...       ... .. .. .. .. .. ..
# 363151         3       6       21  ...     59964       UDP  0  0  0  0  0  0
# 471688         3       6       21  ...     51406       UDP  0  0  0  0  0  0
# 367903         3       6       21  ...     33852       UDP  0  0  0  0  0  0
# 127400         3       6       21  ...     46562       UDP  0  0  0  0  0  0
# 556608         3       6       21  ...        53       UDP  0  0  0  0  0  0
#
#          class  attack_name
# 433551    none    UDP Flood
# 549093    none    UDP Flood
# 158156    none    UDP Flood
# 316834    none    UDP Flood
# 260764  victim    UDP Flood
# ...        ...          ...
# 363151    none    UDP Flood
# 471688    none    UDP Flood
# 367903    none    UDP Flood
# 127400    none    UDP Flood
# 556608    none    UDP Flood
#
# [58000 rows x 26 columns]

# %%
datasets = [blaster_worm_sample,fragmentation_sample,http_flood_sample,icmp_flood_sample,reaper_flood_sample,red_worm_sample,udp_flood_sample]

# %%
all_attacks_dataset = pd.concat(datasets, axis=0, ignore_index=True)

# %%
all_attacks_dataset
# Out:
#              ID  ts_year  ts_month  ts_day  ts_hour  ts_min  ts_second  \
# 0       1663460     2020         1      25        3      46          9
# 1        439871     2020         1      25        3      44         28
# 2        191800     2020         1      25        3      44         11
# 3       3028881     2020         1      25        3      48         41
# 4       1230615     2020         1      25        3      46         33
# ...         ...      ...       ...     ...      ...     ...        ...
# 405995   363152     2019         3       6       21      16         50
# 405996   471689     2019         3       6       21      17         43
# 405997   367904     2019         3       6       21      16         53
# 405998   127401     2019         3       6       21      15          1
# 405999   556609     2019         3       6       21      18         22
#
#         te_year  te_month  te_day  ...  tcp_src_kerb  tcp_src_rpc  \
# 0          2020         1      25  ...        normal       normal
# 1          2020         1      25  ...        normal       normal
# 2          2020         1      25  ...        normal       normal
# 3          2020         1      25  ...        normal       normal
# 4          2020         1      25  ...        normal       normal
# ...         ...       ...     ...  ...           ...          ...
# 405995     2019         3       6  ...        normal       normal
# 405996     2019         3       6  ...        normal       normal
# 405997     2019         3       6  ...        normal       normal
# 405998     2019         3       6  ...        normal       normal
# 405999     2019         3       6  ...        normal       normal
#
#         tcp_dst_p_src  smtp_dst udp_p_r_range p_range_dst  udp_src_p_0  class  \
# 0              normal    normal        normal      normal       normal   none
# 1              normal    normal        normal      normal       normal   none
# 2              normal    normal        normal      normal       normal   none
# 3              normal    normal        normal      normal       normal   none
# 4              normal    normal        normal      normal       normal   none
# ...               ...       ...           ...         ...          ...    ...
# 405995         normal    normal        normal      normal       normal   none
# 405996         normal    normal        normal      normal       normal   none
# 405997         normal    normal        normal      normal       normal   none
# 405998         normal    normal        normal      normal       normal   none
# 405999         normal    normal        normal      normal       normal   none
#
#        attack_a   attack_name
# 0             0  Blaster Worm
# 1             0  Blaster Worm
# 2             0  Blaster Worm
# 3             0  Blaster Worm
# 4             0  Blaster Worm
# ...         ...           ...
# 405995        0     UDP Flood
# 405996        0     UDP Flood
# 405997        0     UDP Flood
# 405998        0     UDP Flood
# 405999        0     UDP Flood
#
# [406000 rows x 86 columns]
